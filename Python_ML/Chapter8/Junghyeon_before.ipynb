# %% [markdown]
# # 신경망 ・ 딥러닝의 응용(필기체 숫자 인식)

# %% [markdown]
# ## MNIST 데이터 베이스

# %%
#-- 리스트 8-1-(1)
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# 훈련용 데이터: 60,000개
# 테스트 데이터: 10,000개
#
# 28x28의 데이터 배열을 28*28을 한 784로 변환한 후에, 신경망을 통과시킨다.

# %%
# - 리스트 8-1-(2)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(1, figsize=(12, 3.2))
plt.subplots_adjust(wspace=0.5)
plt.gray()
for id in range(3):
    plt.subplot(1, 3, id + 1)
    img = x_train[id, :, :]
    plt.pcolor(255 - img)
    plt.text(24.5, 26, "%d" % y_train[id], color='cornflowerblue', fontsize=18)
    plt.xlim(0, 27)
    plt.ylim(27, 0)
    plt.grid('on', color='white')
plt.show()

# %% [markdown]
# ## Keras를 이용한 2층 피드 포워드 네트워크 모델

# %% [markdown]
# 모델을 Sequential()로 정의하고, 16개의 hidden layer, 10개의 output layer를 정의했다.
# Optimizer의 경우 Adam을 사용하였는데, 다른 Optimizer인 RMSProp과 Momentum 방식을 결합해서 만든 Optimizer이다.

# %%
#-- 리스트 8-1-(3)
from keras.utils import np_utils


x_train = x_train.reshape(60000, 784) # (A)
x_train = x_train.astype('float32') # (B)
x_train = x_train / 255 # (C)
num_classes = 10
y_train = np_utils.to_categorical(y_train, num_classes) # (D)


x_test = x_test.reshape(10000, 784)
x_test = x_test.astype('float32')
x_test = x_test / 255
y_test = np_utils.to_categorical(y_test, num_classes)

# %%
#-- 리스트 8-1-(4)
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam


model = Sequential() # (A)
model.add(Dense(16, input_dim=784, activation='sigmoid')) # (B)
model.add(Dense(10, activation='softmax')) # (C)
model.compile(loss='categorical_crossentropy',
optimizer=Adam(), metrics=['accuracy']) # (D)

# %%
#-- 리스트 8-1-(5)
import time


startTime = time.time()
history = model.fit(x_train, y_train, epochs=10, batch_size=1000, verbose=1, validation_data=(x_test, y_test)) # (A)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 1s 10ms/step - loss: 2.0761 - accuracy: 0.3430 - val_loss: 1.7989 - val_accuracy: 0.5606
# Epoch 2/10
# 60/60 [==============================] - 0s 8ms/step - loss: 1.6231 - accuracy: 0.6617 - val_loss: 1.4518 - val_accuracy: 0.7527
# Epoch 3/10
# 60/60 [==============================] - 0s 7ms/step - loss: 1.3327 - accuracy: 0.7849 - val_loss: 1.2036 - val_accuracy: 0.8186
# Epoch 4/10
# 60/60 [==============================] - 0s 8ms/step - loss: 1.1163 - accuracy: 0.8259 - val_loss: 1.0142 - val_accuracy: 0.8480
# Epoch 5/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.9505 - accuracy: 0.8478 - val_loss: 0.8695 - val_accuracy: 0.8640
# Epoch 6/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.8230 - accuracy: 0.8613 - val_loss: 0.7587 - val_accuracy: 0.8755
# Epoch 7/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.7250 - accuracy: 0.8721 - val_loss: 0.6729 - val_accuracy: 0.8829
# Epoch 8/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.6486 - accuracy: 0.8797 - val_loss: 0.6065 - val_accuracy: 0.8879
# Epoch 9/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.5888 - accuracy: 0.8859 - val_loss: 0.5546 - val_accuracy: 0.8928
# Epoch 10/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.5412 - accuracy: 0.8911 - val_loss: 0.5124 - val_accuracy: 0.8965
# Test loss: 0.5123919248580933
# Test accuracy: 0.8964999914169312
# Computation time:6.141 sec

# %%
#-- 리스트 8-1-(6)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure(1, figsize=(10, 4))
plt.subplots_adjust(wspace=0.5)


plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='training', color='black')
plt.plot(history.history['val_loss'], label='test',
         color='cornflowerblue')
plt.ylim(0, 10)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')


plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='training', color='black')
plt.plot(history.history['val_accuracy'],label='test', color='cornflowerblue')
plt.ylim(0, 1)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()

# %%
#-- 리스트 8-1-(7)
def show_prediction():
    n_show = 96
    y = model.predict(x_test) # (A)
    plt.figure(2, figsize=(12, 8))
    plt.gray()
    for i in range(n_show):
        plt.subplot(8, 12, i + 1)
        x = x_test[i, :]
        x = x.reshape(28, 28)
        plt.pcolor(1 - x)
        wk = y[i, :]
        prediction = np.argmax(wk)
        plt.text(22, 25.5, "%d" % prediction, fontsize=12)
        if prediction != np.argmax(y_test[i, :]):
            plt.plot([0, 27], [1, 1], color='cornflowerblue', linewidth=5)
        plt.xlim(0, 27)
        plt.ylim(27, 0)
        plt.xticks([], "")
        plt.yticks([], "")
#-- 메인
show_prediction()
plt.show()

# %% [markdown]
# ## Activation Function(활성함수)

# %% [markdown]
# 기존의 활성함수로는 Sigmoid 함수를 사용했지만, 최근에는 max(x, 0)인 ReLU 함수를 주로 사용한다.
# Sigmoid 함수의 경우, 입력 x가 커질수록 1에 가까워지고 그에 따라서 편미분값은 0에 가까워진다.
# 이는 Gradient Descent의 학습이 늦어지는 문제점이 있다. 이에 대안으로 등장한 함수가 ReLU 함수이다.
#
# Sigmoid 함수를 사용했을때 Accuracy가 0.89인 반면, ReLU 함수를 사용했을때는 0.92를 기록했다.

# %%
#-- 리스트 8-1-(8)
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam


model = Sequential()
model.add(Dense(16, input_dim=784, activation='relu')) # (A)
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(), metrics=['accuracy'])


startTime = time.time()
history = model.fit(x_train, y_train, batch_size=1000, epochs=10,
                    verbose=1, validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 1s 10ms/step - loss: 1.5320 - accuracy: 0.5571 - val_loss: 0.8700 - val_accuracy: 0.8053
# Epoch 2/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.6760 - accuracy: 0.8370 - val_loss: 0.5129 - val_accuracy: 0.8746
# Epoch 3/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4690 - accuracy: 0.8782 - val_loss: 0.4016 - val_accuracy: 0.8953
# Epoch 4/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.3884 - accuracy: 0.8952 - val_loss: 0.3490 - val_accuracy: 0.9058
# Epoch 5/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.3451 - accuracy: 0.9037 - val_loss: 0.3190 - val_accuracy: 0.9114
# Epoch 6/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.3173 - accuracy: 0.9119 - val_loss: 0.2994 - val_accuracy: 0.9149
# Epoch 7/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.2983 - accuracy: 0.9167 - val_loss: 0.2842 - val_accuracy: 0.9180
# Epoch 8/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.2837 - accuracy: 0.9208 - val_loss: 0.2731 - val_accuracy: 0.9215
# Epoch 9/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.2724 - accuracy: 0.9237 - val_loss: 0.2634 - val_accuracy: 0.9244
# Epoch 10/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.2625 - accuracy: 0.9260 - val_loss: 0.2563 - val_accuracy: 0.9258
# Test loss: 0.25629276037216187
# Test accuracy: 0.9258000254631042
# Computation time:6.005 sec

# %%
# 리스트 8-1-(9)
show_prediction()
plt.show()

# %%
#-- 리스트 8-1-(10)
# 1층째의 무게 시각화
w = model.layers[0].get_weights()[0]
plt.figure(1, figsize=(12, 3))
plt.gray()
plt.subplots_adjust(wspace=0.35, hspace=0.5)
for i in range(16):
    plt.subplot(2, 8, i + 1)
    w1 = w[:, i]
    w1 = w1.reshape(28, 28)
    plt.pcolor(-w1)
    plt.xlim(0, 27)
    plt.ylim(27, 0)
    plt.xticks([], "")
    plt.yticks([], "")
    plt.title("%d" % i)
plt.show()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## 공간 필터

# %% [markdown]
# 기존의 방식은 28x28의 이미지를 784x1로 flatten해서 입력값에 넣어주었다.
# 그러나 공간 필터를 이용하면 28x28의 이미지 모양 그대로 유지한채로 학습이 가능하다.
# 이러한 방식을 흔히 CNN이라고 부른다.

# %%
#-- 리스트 8-2-(1)
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 28, 28, 1)
x_test = x_test.reshape(10000, 28, 28, 1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
num_classes = 10
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# %% [markdown]
# 필터의 값을 변경하는 것으로 대각선 엣지 강조, 이미지 스무딩 등의 다양한 처리가 가능하다.
# 흰색: 0, 검정색: 1의 값을 가지게된다.

# %%
#-- 리스트 8-2-(2)
import matplotlib.pyplot as plt
# %matplotlib inline


id_img = 2
myfil1 = np.array([[1, 1, 1],
                   [1, 1, 1],
                   [-2, -2, -2]], dtype=float) # (A)
myfil2 = np.array([[-2, 1, 1],
                   [-2, 1, 1],
                   [-2, 1, 1]], dtype=float) # (B)


x_img = x_train[id_img, :, :, 0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h, img_w)
out_img1 = np.zeros_like(x_img)
out_img2 = np.zeros_like(x_img)

# 필터 처리
for ih in range(img_h - 3):
    for iw in range(img_w - 3):
        img_part = x_img[ih:ih + 3, iw:iw + 3]
        out_img1[ih + 1, iw + 1] = np.dot(img_part.reshape(-1), myfil1.reshape(-1))
        out_img2[ih + 1, iw + 1] = np.dot(img_part.reshape(-1), myfil2.reshape(-1)) 


# - 표시
plt.figure(1, figsize=(12, 3.2))
plt.subplots_adjust(wspace=0.5)
plt.gray()
plt.subplot(1, 3, 1)
plt.pcolor(1 - x_img)
plt.xlim(-1, 29)
plt.ylim(29, -1)
plt.subplot(1, 3, 2)
plt.pcolor(-out_img1)
plt.xlim(-1, 29)
plt.ylim(29, -1)
plt.subplot(1, 3, 3)
plt.pcolor(-out_img2)
plt.xlim(-1, 29)
plt.ylim(29, -1)
plt.show()

# %% [markdown]
# ## CNN(합성곱 신경망)

# %% [markdown]
# 필터를 신경망에 적용시켜서 학습을 시킨다.
# 기존의 가중치 -> 필터의 값
# 정확도의 경우 ReLU 함수를 이용한 2층 신경망보다 더 증가한 0.97을 나타냈다.

# %%
|#-- 리스트 8-2-(3)
import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D # CNN을 사용
from keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
import time


model = Sequential()
model.add(Conv2D(8, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu')) # (3, 3)의 필터를 8개 사용
model.add(Flatten()) # (B)
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
startTime = time.time()
history = model.fit(x_train, y_train, batch_size=1000, epochs=20, verbose=1, validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 11s 180ms/step - loss: 1.0557 - accuracy: 0.8032 - val_loss: 0.3888 - val_accuracy: 0.9013
# Epoch 2/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.3201 - accuracy: 0.9139 - val_loss: 0.2498 - val_accuracy: 0.9343
# Epoch 3/20
# 60/60 [==============================] - 12s 203ms/step - loss: 0.2347 - accuracy: 0.9363 - val_loss: 0.2012 - val_accuracy: 0.9471
# Epoch 4/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.1931 - accuracy: 0.9470 - val_loss: 0.1697 - val_accuracy: 0.9536
# Epoch 5/20
# 60/60 [==============================] - 11s 177ms/step - loss: 0.1657 - accuracy: 0.9541 - val_loss: 0.1492 - val_accuracy: 0.9585
# Epoch 6/20
# 60/60 [==============================] - 11s 179ms/step - loss: 0.1437 - accuracy: 0.9608 - val_loss: 0.1317 - val_accuracy: 0.9652
# Epoch 7/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.1276 - accuracy: 0.9653 - val_loss: 0.1192 - val_accuracy: 0.9681
# Epoch 8/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.1139 - accuracy: 0.9699 - val_loss: 0.1101 - val_accuracy: 0.9698
# Epoch 9/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.1036 - accuracy: 0.9725 - val_loss: 0.1018 - val_accuracy: 0.9712
# Epoch 10/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.0949 - accuracy: 0.9748 - val_loss: 0.0948 - val_accuracy: 0.9726
# Epoch 11/20
# 60/60 [==============================] - 13s 215ms/step - loss: 0.0875 - accuracy: 0.9773 - val_loss: 0.0898 - val_accuracy: 0.9745
# Epoch 12/20
# 60/60 [==============================] - 11s 177ms/step - loss: 0.0813 - accuracy: 0.9785 - val_loss: 0.0856 - val_accuracy: 0.9748
# Epoch 13/20
# 60/60 [==============================] - 11s 179ms/step - loss: 0.0759 - accuracy: 0.9804 - val_loss: 0.0809 - val_accuracy: 0.9761
# Epoch 14/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.0712 - accuracy: 0.9810 - val_loss: 0.0791 - val_accuracy: 0.9767
# Epoch 15/20
# 60/60 [==============================] - 11s 177ms/step - loss: 0.0670 - accuracy: 0.9822 - val_loss: 0.0769 - val_accuracy: 0.9771
# Epoch 16/20
# 60/60 [==============================] - 11s 179ms/step - loss: 0.0630 - accuracy: 0.9834 - val_loss: 0.0737 - val_accuracy: 0.9771
# Epoch 17/20
# 60/60 [==============================] - 11s 179ms/step - loss: 0.0600 - accuracy: 0.9837 - val_loss: 0.0728 - val_accuracy: 0.9783
# Epoch 18/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.0573 - accuracy: 0.9845 - val_loss: 0.0707 - val_accuracy: 0.9784
# Epoch 19/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.0545 - accuracy: 0.9850 - val_loss: 0.0679 - val_accuracy: 0.9786
# Epoch 20/20
# 60/60 [==============================] - 11s 178ms/step - loss: 0.0521 - accuracy: 0.9859 - val_loss: 0.0669 - val_accuracy: 0.9796
# Test loss: 0.06694342195987701
# Test accuracy: 0.9796000123023987
# Computation time:219.784 sec

# %%
#-- 리스트 8-1-(7)
def show_prediction():
    n_show = 96
    y = model.predict(x_test) # (A)
    plt.figure(2, figsize=(12, 8))
    plt.gray()
    for i in range(n_show):
        plt.subplot(8, 12, i + 1)
        x = x_test[i, :]
        x = x.reshape(28, 28)
        plt.pcolor(1 - x)
        wk = y[i, :]
        prediction = np.argmax(wk)
        plt.text(22, 25.5, "%d" % prediction, fontsize=12)
        if prediction != np.argmax(y_test[i, :]):
            plt.plot([0, 27], [1, 1], color='cornflowerblue', linewidth=5)
        plt.xlim(0, 27)
        plt.ylim(27, 0)
        plt.xticks([], "")
        plt.yticks([], "")

# %%
# 리스트 8-2-(4)
show_prediction()
plt.show()

# %%
# 리스트 8-2-(5)
plt.figure(1, figsize=(12, 2.5))
plt.gray()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.subplot(2, 9, 10)
id_img = 12
x_img = x_test[id_img, :, :, 0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h, img_w)
plt.pcolor(-x_img)
plt.xlim(0, img_h)
plt.ylim(img_w, 0)
plt.xticks([], "")
plt.yticks([], "")
plt.title("Original")


w = model.layers[0].get_weights()[0] # (A)
max_w = np.max(w)
min_w = np.min(w)
for i in range(8):
    plt.subplot(2, 9, i + 2)
    w1 = w[:, :, 0, i]
    w1 = w1.reshape(3, 3)
    plt.pcolor(-w1, vmin=min_w, vmax=max_w)
    plt.xlim(0, 3)
    plt.ylim(3, 0)
    plt.xticks([], "")
    plt.yticks([], "")
    plt.title("%d" % i)
    plt.subplot(2, 9, i + 11)
    out_img = np.zeros_like(x_img)
    # 필터 처리
    for ih in range(img_h - 3):
        for iw in range(img_w - 3):
            img_part = x_img[ih:ih + 3, iw:iw + 3]
            out_img[ih + 1, iw + 1] = np.dot(img_part.reshape(-1), w1.reshape(-1))
    plt.pcolor(-out_img)
    plt.xlim(0, img_w)
    plt.ylim(img_h, 0)
    plt.xticks([], "")
    plt.yticks([], "")
plt.show()

# %% [markdown]
# CNN에 풀링과 드롭아웃을 적용하여 계층의 수를 늘리고 최종적으로 네트워크를 구축
# 정확도를 0.99까지 끌어올림

# %%
# 리스트 8-2-(6)
import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
import time


model = Sequential()
model.add(Conv2D(16, (3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) # (A)
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) # (B)
model.add(Dropout(0.25)) # (C)
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25)) # (D)
model.add(Dense(num_classes, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])


startTime = time.time()


history = model.fit(x_train, y_train, batch_size=1000, epochs=20, verbose=1, validation_data=(x_test, y_test))


score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 71s 1s/step - loss: 0.6495 - accuracy: 0.7983 - val_loss: 0.1129 - val_accuracy: 0.9672
# Epoch 2/20
# 60/60 [==============================] - 70s 1s/step - loss: 0.1281 - accuracy: 0.9617 - val_loss: 0.0571 - val_accuracy: 0.9830
# Epoch 3/20
# 60/60 [==============================] - 71s 1s/step - loss: 0.0869 - accuracy: 0.9745 - val_loss: 0.0424 - val_accuracy: 0.9866
# Epoch 4/20
# 60/60 [==============================] - 72s 1s/step - loss: 0.0674 - accuracy: 0.9804 - val_loss: 0.0354 - val_accuracy: 0.9890
# Epoch 5/20
# 60/60 [==============================] - 75s 1s/step - loss: 0.0550 - accuracy: 0.9831 - val_loss: 0.0317 - val_accuracy: 0.9901
# Epoch 6/20
# 60/60 [==============================] - 80s 1s/step - loss: 0.0488 - accuracy: 0.9849 - val_loss: 0.0291 - val_accuracy: 0.9905
# Epoch 7/20
# 60/60 [==============================] - 72s 1s/step - loss: 0.0423 - accuracy: 0.9866 - val_loss: 0.0283 - val_accuracy: 0.9910
# Epoch 8/20
# 60/60 [==============================] - 73s 1s/step - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.0288 - val_accuracy: 0.9910
# Epoch 9/20
# 60/60 [==============================] - 74s 1s/step - loss: 0.0355 - accuracy: 0.9890 - val_loss: 0.0229 - val_accuracy: 0.9926
# Epoch 10/20
# 60/60 [==============================] - 71s 1s/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0247 - val_accuracy: 0.9917
# Epoch 11/20
# 60/60 [==============================] - 73s 1s/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.0216 - val_accuracy: 0.9930
# Epoch 12/20
# 60/60 [==============================] - 78s 1s/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.0244 - val_accuracy: 0.9921
# Epoch 13/20
# 60/60 [==============================] - 91s 2s/step - loss: 0.0259 - accuracy: 0.9921 - val_loss: 0.0209 - val_accuracy: 0.9931
# Epoch 14/20
# 60/60 [==============================] - 73s 1s/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.0209 - val_accuracy: 0.9934
# Epoch 15/20
# 60/60 [==============================] - 76s 1s/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0200 - val_accuracy: 0.9928
# Epoch 16/20
# 60/60 [==============================] - 75s 1s/step - loss: 0.0205 - accuracy: 0.9935 - val_loss: 0.0184 - val_accuracy: 0.9937
# Epoch 17/20
# 60/60 [==============================] - 74s 1s/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0188 - val_accuracy: 0.9936
# Epoch 18/20
# 60/60 [==============================] - 73s 1s/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0.0185 - val_accuracy: 0.9935
# Epoch 19/20
# 60/60 [==============================] - 73s 1s/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.0190 - val_accuracy: 0.9936
# Epoch 20/20
# 60/60 [==============================] - 73s 1s/step - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.0208 - val_accuracy: 0.9930
# Test loss: 0.020836766809225082
# Test accuracy: 0.9929999709129333
# Computation time:1527.338 sec

# %%
# 리스트 8-2-(7)
show_prediction()
plt.show()
